# %% [markdown]
# <a href="https://colab.research.google.com/github/pattaradanai-lks/Plotly/blob/main/Plotly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px


df = pd.read_csv('https://raw.githubusercontent.com/pattaradanai-lks/Plotly/main/forbes2000-2022.csv')
df.head()
# Out:
#    rank                             global company        country     sales   \
# 0      1                        Berkshire Hathaway  United States  $276.09 B
# 1      2                                      ICBC          China  $208.13 B
# 2      3  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia  $400.38 B
# 3      4                            JPMorgan Chase  United States  $124.54 B
# 4      5                   China Construction Bank          China  $202.07 B
#
#      profit        assets market value
# 0    $89.8 B    $958.78 B    $741.48 B
# 1   $54.03 B  $5,518.51 B    $214.43 B
# 2  $105.36 B    $576.04 B  $2,292.08 B
# 3   $42.12 B  $3,954.69 B    $374.45 B
# 4   $46.89 B  $4,746.95 B    $181.32 B

# %%
df.shape
# Out:
# (2000, 7)

# %%
df=df.head(100)

# %%
df.columns
# Out:
# Index(['rank ', 'global company', 'country', 'sales ', 'profit ', 'assets',
#        'market value'],
#       dtype='object')

# %%
# ตัดเครื่องหมาย $ และ B ออกจากคอลัมน์ที่ต้องการ
df['sales '] = df['sales '].astype(str).str.replace('$', '').str.replace('B', '').astype(float)
df['profit '] = df['profit '].astype(str).str.replace('$', '').str.replace('B', '').astype(float)
df['market value'] = df['market value'].astype(str).str.replace('$', '').str.replace('B', '').str.replace(',', '').astype(float)

# %%
fig = px.scatter(data_frame=df, x='profit ', y='sales ',
                 size='market value', color="country",
                 hover_name="global company", size_max=80,
                 labels={'profit ': 'Profit (Billion)$', 'sales ': 'Sales (Billion)$','market value':'Market value (Billion)$'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f72cfc1c-c476-494a-a804-676f20be3302" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f72cfc1c-c476-494a-a804-676f20be3302")) {                    Plotly.newPlot(                        "f72cfc1c-c476-494a-a804-676f20be3302",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry=United States\u003cbr\u003eProfit (Billion)$=%{x}\u003cbr\u003eSales (Billion)$=%{y}\u003cbr\u003eMarket value (Billion)$=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Berkshire Hathaway","JPMorgan Chase","Amazon","Apple","Bank of America","Alphabet","Microsoft","ExxonMobil","Wells Fargo","Verizon Communications","AT&T","UnitedHealth Group","Walmart","Chevron","Citigroup","Comcast","Meta Platforms","Morgan Stanley","Goldman Sachs Group","Johnson & Johnson","CVS Health","Pfizer"],"legendgroup":"United States","marker":{"color":"#636efa","size":[741.48,374.45,1468.